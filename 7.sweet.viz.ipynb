# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fftpack import fft
from scipy import signal
import numpy as np
import seaborn as sns
from sklearn.preprocessing import scale

# %matplotlib inline
plt.style.use('ggplot')

# %%
sws_raw_data = pd.read_csv('sws_2017-04-22_12:52:05.csv', infer_datetime_format=True)
sws_raw_data.plot(figsize=(15, 10))

# %%
top_raw_data = pd.read_csv('top_2017-04-22_11:43:48.csv', infer_datetime_format=True)
top_raw_data.plot(figsize=(15, 10))

# %%
bot_raw_data = pd.read_csv('bot_2017-04-22_11:45:48.csv', infer_datetime_format=True)
bot_raw_data.plot(figsize=(15, 10))

# %%
left_raw_data = pd.read_csv('left_2017-04-22_12:26:52.csv', infer_datetime_format=True)
left_raw_data.plot(figsize=(15, 10))

# %%
right_raw_data = pd.read_csv('right_2017-04-22_12:26:40.csv', infer_datetime_format=True)
right_raw_data.plot(figsize=(15, 10))

# %%
sampling_rate = 1.0/10.0
imu_signal = sws_raw_data['AccY']
N = len(imu_signal)
yf = fft(imu_signal)
xf = np.linspace(0.0, 1.0/(2.0*sampling_rate), N/2)
plt.plot(xf[1:N/2], 2.0/N * np.abs(yf[1:N/2]))
